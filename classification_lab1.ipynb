# %%
# !pip install langchain_community
# !pip install replicate

# %%
from langchain_community.llms import Replicate
import os
from google.colab import userdata
import time # Import the time module
# Establecer el token de API
api_token = userdata.get('kikopol')
os.environ["REPLICATE_API_TOKEN"] = api_token
# Configuración del modelo
model = "ibm-granite/granite-3.2-8b-instruct"
output = Replicate(
 model=model,
 replicate_api_token=api_token,
)
# Definir las opiniones de los clientes
customer_reviews = [
 "La batería dura todo el día y el rendimiento es excelente."
 "La pantalla es demasiado tenue en exteriores, pero me encantan los colores en interiores."
 "Este teléfono es lento y falla cuando abro ciertas aplicaciones."
]
# Refinar la solicitud para incluir reseñas
reviews_text = "\n".join([f"Review {i+1}: {review}" for i, review
in enumerate(customer_reviews)])
prompt = f"""
Clasifica estas reseñas como positivas, negativas o mixtas:
{reviews_text}
"""
# Invocar el modelo con la solicitud de ejemplo
response = output.invoke(prompt)
# Imprimir la respuesta
print("Granite Model Response:\n")
print(response)
time.sleep(10) # Add a delay of 10 seconds

# Definir una solicitud refinada
refined_prompt = f"""
Clasifica estas reseñas como positivas, negativas o mixtas y
etiqueta las categorías pertinentes (duración de la batería,
calidad de la pantalla o rendimiento):
{reviews_text}
"""
# Invocar el modelo con la solicitud de ejemplo
respuesta = output.invoke(refined_prompt)
# Imprimir la respuesta
print("Granite Model Refined Response:\n")
print(respuesta)
time.sleep(10) # Add a delay of 10 seconds
# Definir la solicitud para completar la tarea en 2 pasos
multitask_prompt = f"""
Completa la tarea en 2 pasos.
Paso 1: Clasificar estas reseñas como positivas, negativas o
mixtas.
Paso 2: Para cada reseña, identificar las categorías
pertinentes: duración de la batería, calidad de la pantalla o
rendimiento.
{reviews_text}
"""
respuesta2 = output.invoke(multitask_prompt)
print("Granite Model Response:\n")
print(respuesta2)
time.sleep(10) # Add a delay of 10 seconds

# Definir el ejemplo para guiar el modelo
formatted_prompt = f"""
Clasifica estas reseñas como positivas, negativas o mixtas y
etiqueta las categorías pertinentes. Utiliza este formato:
- Sentimiento: [Sentimiento]
- Categorías: [Categorías].
{reviews_text}
"""
# Invocar el modelo con la solicitud
respuesta3 = output.invoke(formatted_prompt)
# Imprimir la respuesta
print("Granite Model Formatted Response:\n")
print(respuesta3)
# Out:
# Granite Model Response:
#
# Review 1: Mixta
#
# Explicación:
#
# 1. "La batería dura todo el día y el rendimiento es excelente." - Esta parte es positiva, ya que destaca las características favorables del teléfono.
#
# 2. "La pantalla es demasiado tenue en exteriores, pero me encantan los colores en interiores." - Esta parte es mixta, ya que menciona un problema (poca luminosidad en exteriores) pero también una característica positiva (colores atractivos en interiores).
#
# 3. "Este teléfono es lento y falla cuando abro ciertas aplicaciones." - Esta parte es negativa, ya que señala problemas de rendimiento y estabilidad en el dispositivo.
#
# En conjunto, la reseña presenta tanto aspectos positivos como negativos, lo que la clasifica como mixta.
# Granite Model Refined Response:
#
# Review 1:
#
# Categorías:
# - Duración de la batería: Positiva
# - Calidad de la pantalla: Mixta (Tenue en exteriores, buenos colores en interiores)
# - Rendimiento: Negativa (Lento y falla con ciertas aplicaciones)
#
# Explicación:
#
# 1. Duración de la batería: El usuario menciona que la batería dura todo el día, lo que indica una evaluación positiva.
# 2. Calidad de la pantalla: Aunque la pantalla es tenue en exteriores, el usuario aprecia los colores en interiores, lo que resulta en una valoración mixta.
# 3. Rendimiento: El teléfono se describe como lento y falla al abrir ciertas aplicaciones, lo que indica una evaluación negativa.
# Granite Model Response:
#
# Paso 1: Clasificación de las reseñas
#
# 1. Reseña 1: Mixta
#
# Paso 2: Identificación de categorías pertinentes
#
# 1. Reseña 1:
#    - Duración de la batería: Positiva (La batería dura todo el día)
#    - Rendimiento: Negativa (Este teléfono es lento y falla cuando abro ciertas aplicaciones)
#    - Calidad de la pantalla: Mixta (La pantalla es demasiado tenue en exteriores, pero me encantan los colores en interiores)
# Granite Model Formatted Response:
#
# - Sentimiento: Mixto
# - Categorías: Batería, Rendimiento, Pantalla, Velocidad de la aplicación
#
# Explicación:
#
# 1. La batería dura todo el día y el rendimiento es excelente. - Sentimiento Positivo
#    - Categoría: Batería, Rendimiento
#
# 2. La pantalla es demasiado tenue en exteriores, pero me encantan los colores en interiores. - Sentimiento Neutral/Mixto
#    - Categoría: Pantalla
#
# 3. Este teléfono es lento y falla cuando abro ciertas aplicaciones. - Sentimiento Negativo
#    - Categoría: Velocidad de la aplicación
#
# Dado que hay tanto aspectos positivos (batería y rendimiento) como negativos (pantalla tenue y velocidad de la aplicación lenta), esta reseña se clasifica como "mixta".

# %%
from langchain_community.llms import Replicate
import os
from google.colab import userdata
import time # Import the time module
# Establecer el token de API
api_token = userdata.get('kikopol')
os.environ["REPLICATE_API_TOKEN"] = api_token
# Configuración del modelo
model = "ibm-granite/granite-3.2-8b-instruct"
output = Replicate(
 model=model,
 replicate_api_token=api_token,
)
customer_meetings = [
"""
La reunión comenzó con una discusión sobre el presupuesto de
marketing del tercer trimestre. Se decidió que el 40 % del
presupuesto se destinará a anuncios digitales, el 30 % a eventos y
el 30 % a campañas en redes sociales. El equipo enfatizó la
necesidad de concretar asociaciones con influencers para aumentar
la visibilidad de la marca y el marketing por correo electrónico
para impulsar la interacción directa. El próximo mes se lanzará un
programa piloto para probar nuevos formatos de anuncios y el
equipo revisará los resultados a finales del tercer trimestre.
Posteriormente, el equipo discutió las métricas de rendimiento de
la campaña. El seguimiento del ROI será una máxima prioridad y se
realizarán ajustes en función de los datos de rendimiento.
El equipo de eventos planteó inquietudes sobre la asignación de
recursos para las próximas ferias comerciales y se acordó que se
reasignarían $10.000 adicionales para cubrir estos gastos.
Por último, el equipo revisó nuevos conceptos creativos para la
próxima campaña y decidió continuar con el Concepto 8, que tuvo
mejores resultados entre los focus groups. Se ultimaron los plazos
para la entrega de los activos de campaña: todos los entregables
deben presentarse a más tardar el 15 de julio.
"""
]
# Refinar la solicitud para incluir reseñas
reviews_text = "\n".join([f"Review {i+1}: {review}" for i, review
in enumerate(customer_meetings)])
prompt = f"""
Resume esta reunión:
{reviews_text}
"""
# Invocar el modelo con la solicitud de ejemplo
respuesta = output.invoke(prompt)
# Imprimir la respuesta
print("Granite Model Response:\n")
print(respuesta)
time.sleep(20) # Add a delay of 20 seconds

# Definir una solicitud refinada
refined_prompt = f"""
Resume esta reunión en tres oraciones:
{reviews_text}
"""
# Invocar el modelo con la solicitud refinada
respuesta2 = output.invoke(refined_prompt)
# Imprimir la respuesta
print("Granite Model Refined Response:\n")
print(respuesta2)
time.sleep(20) # Add a delay of 20 seconds

# Definir la solicitud con una solicitud refinada de aspectos prioritarios
refined_focusarea_prompt = f"""
Resume esta reunión centrándote en los puntos clave, las
decisiones tomadas y las acciones pendientes:
{reviews_text}
"""
respuesta3 = output.invoke(refined_focusarea_prompt)
print("Granite Model Response for refined focus area response:\n")
print(respuesta3)
time.sleep(20) # Add another delay of 20 seconds

# Definir la solicitud con una solicitud de resultado refinada
refined_outputformat_prompt = f"""
Resume esta reunión en un formato estructurado utilizando los
siguientes títulos: Puntos clave discutidos, Decisiones tomadas y
Acciones pendientes. Menciona los cronogramas.
Incluye solo dos viñetas concisas para cada título.
{reviews_text}
"""
response4 = output.invoke(refined_outputformat_prompt)
print("Granite Model Response for refined output format response:\n")
print(response4)
# Out:
# Granite Model Response:
#
# Resumen de la reunión:
#
# 1. Presupuesto de marketing para el tercer trimestre:
#    - 40% para anuncios digitales
#    - 30% para eventos
#    - 30% para campañas en redes sociales
#    - Se planea establecer asociaciones con influencers y utilizar el marketing por correo electrónico para mejorar la interacción directa.
#    - Se lanzará un programa piloto para probar nuevos formatos de anuncios, con una revisión de los resultados a finales del tercer trimestre.
#
# 2. Métricas de rendimiento de la campaña:
#    - Se priorizará el seguimiento del ROI.
#    - Se realizarán ajustes basados en los datos de rendimiento.
#
# 3. Asignación de recursos para eventos:
#    - Se asignarán $10.000 adicionales para cubrir los gastos de las próximas ferias comerciales.
#
# 4. Conceptos creativos para la próxima campaña:
#    - Se decidió continuar con el Concepto 8, que obtuvo mejores resultados en los focus groups.
#    - Se establecieron plazos para la entrega de activos de campaña: todos los entregables deben presentarse antes del 15 de julio.
# Granite Model Refined Response:
#
# En la reunión, se determinó que el presupuesto de marketing del tercer trimestre se dividirá en un 40% para anuncios digitales, un 30% para eventos y un 30% para campañas en redes sociales, con un enfoque en asociaciones con influencers y marketing por correo electrónico. Se planea lanzar un programa piloto para probar nuevos formatos de anuncios y se priorizará el seguimiento del ROI para realizar ajustes según los datos de rendimiento. Además, se asignarán $10.000 adicionales para eventos y se seleccionó el Concepto 8 para la próxima campaña, con un plazo de entrega de todos los activos de campaña el 15 de julio.
# Granite Model Response for refined focus area response:
#
# **Resumen de la Reunión:**
#
# 1. **Presupuesto de Marketing del Tercer Trimestre:**
#    - Se asignó un presupuesto del 40% a anuncios digitales.
#    - El 30% se destinará a eventos.
#    - Otro 30% se utilizará para campañas en redes sociales.
#    - Se enfatizó la importancia de asociarse con influencers y utilizar el marketing por correo electrónico para aumentar la interacción directa.
#    - Se lanzará un programa piloto para probar nuevos formatos de anuncios, con una revisión de los resultados a finales del tercer trimestre.
#
# 2. **Métricas de Rendimiento y ROI:**
#    - El seguimiento del ROI será una prioridad máxima.
#    - Se realizarán ajustes basados en los datos de rendimiento.
#
# 3. **Recursos para Eventos:**
#    - Se asignarán $10.000 adicionales para cubrir los gastos de las próximas ferias comerciales.
#
# 4. **Conceptos Creativos para la Campaña:**
#    - Se decidió continuar con el Concepto 8, que mostró mejores resultados en los focus groups.
#    - Los plazos para la entrega de los activos de campaña se han establecido: todos los entregables deben presentarse a más tardar el 15 de julio.
#
# **Acciones Pendientes:**
#
# - Implementar la asociación con influencers y el marketing por correo electrónico.
# - Monitorear y ajustar el presupuesto según los resultados del programa piloto de anuncios.
# - Preparar y presentar todos los activos de campaña antes del 15 de julio.
# - Continuar el seguimiento y ajuste de las métricas de rendimiento y ROI.
# Granite Model Response for refined output format response:
#
# **Puntos clave discutidos:**
#
# - **Presupuesto de marketing:** Se asignó un 40% para anuncios digitales, 30% para eventos y 30% para campañas en redes sociales. Se destacó la importancia de asociaciones con influencers y marketing por correo electrónico.
# - **Métricas de rendimiento:** Se enfatizó el seguimiento del ROI y la posibilidad de ajustar estrategias basándose en los datos de rendimiento.
# - **Recursos para eventos:** Se asignaron $10.000 adicionales para cubrir los costos de las próximas ferias comerciales.
# - **Conceptos creativos:** Se decidió continuar con el Concepto 8, que mostró mejores resultados en los focus groups.
#
# **Decisiones tomadas:**
#
# - **Presupuesto de marketing:** Distribución específica del presupuesto para anuncios digitales, eventos y redes sociales.
# - **Asignación de recursos:** Reasignación de $10.000 adicionales para eventos.
# - **Concepto creativo:** Selección del Concepto 8 para la próxima campaña.
#
# **Acciones pendientes:**
#
# - **Programa piloto:** Lanzamiento del programa piloto para probar nuevos formatos de anuncios, con revisión de resultados a finales del tercer trimestre.
# - **Entregables de campaña:** Todos los activos de la campaña deben presentarse a más tardar el 15 de julio.
# - **Seguimiento de métricas:** Implementación del seguimiento del ROI y ajustes basados en los datos de rendimiento.
